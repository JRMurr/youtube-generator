# %% [markdown]
# Before doing anything seed the random numbers to have reproducible results

# %%
from numpy.random import seed
seed(6504)
from tensorflow import set_random_seed
set_random_seed(6505)

import numpy as np

# %%
from src.features.build_features import *
# Out:
# Using TensorFlow backend.

# %%
df = getCaptionDF()
df
# Out:
#                                    id  \
# 0    -0FofY0i4JCwiB9vcA5xymFAY6T_zGa-
# 1    -3SGKmjDClyo7rhf3OeYhoojuMi1ftyA
# 2    -7FC8UoVpEcY_gSpoN-E63CaPyffT9ck
# 3    -CsVDRXQfQDtLc3iMH5ke-kyqqjQsLv9
# 4    -D06gGPkGOvbGYlzLZ6nbs2cUL6r3oS5
# 5    -EyiI4OoZ4phqf_EnB0tRk3wGgUYciPC
# 6    -QI6NKRhFWwaUDZ4mGw-BmH5noZczhng
# 7    -RMA5VzmDbZGRldSBdNbp05q4638j9xs
# 8    -UnwDbxSv6PzxA8BZHqaXF8QkfRwt7Eq
# 9    -eTUcb63ohHm6lqTH4XLRJz0NLgR-R71
# 10   -haM7vbyggMiFCR-41Z-IA3dKab_UAQR
# 11   -hiKbBDeey0huBFq4Mk0ZU-m85HYDW93
# 12   -sW692iuh2eHLqba3HiHA4cteZaaFIbZ
# 13   -t4S3QRtUmBQxaMqBpS_NQm1O21IVuMQ
# 14   -tuM2C_MSuqOmDw9rzJGMPUPwUhKcVDV
# 15   -w5ejhjhYFg8WTaTcG8HvG7yeLdC_PNN
# 16   01WlDfB1Sge-1juoGbmSRGSmRc53MXbU
# 17   05RT2TozmNXXUR76Z9sj4c72XoM9FaO3
# 18   0CF6sadub7gVkH8lQtL6uXaS4il2HBmz
# 19   0MYy5OU7Tblf9y2FsiDwUXk-1KAmiTYJ
# 20   0a3kjqIFVILQM42Wx8GnxpzjJWVZsdvw
# 21   0b99pMP0MKjbHv1Vb-xrHR4M6Uws3UyY
# 22   0bGrNl1uYprz0QbUpvlo6qlej_Q-aorV
# 23   0dL533BOGa0xW5WMsOnIUcN6N-pgNj3X
# 24   0dV8AEc2z8EvsrmDWw9lCQA2SrNWwgbO
# 25   0gWlHEU6uBeP_4wiXyzCbvwwaR9hEq2S
# 26   0j8j9EcwPioLfV89xkOS0WD182ZuHP4W
# 27   0vRGTv0UW2OeGk-kKw8Q5tXLupjV4NPY
# 28   11SGeZ4eD8dGML6b7m7HLfi0DEaezd3V
# 29   16ZLPMXyNepezfKaCub_Ngxg9tiuiEew
# ..                                ...
# 644  w77RRS2gjL4r959tELihciRYtzFsYrpv
# 645  wi2Hme6IK91rdPNOUVCF2KGr8WDw0nQk
# 646  wiZR8Eb5u1GtLFc37dSQBLXVXyBR-KwI
# 647  wniuEuf3KSf9F1UUoywk-MlqBllG2N0j
# 648  x3gCBLxXWj89URn92xtex-TFlcENrJTt
# 649  x8G1HPPwL8v3QIN2bVqGxQ7gyfXgbd_P
# 650  x8WczVgdgv_7WVulU0G7oUJZD-5dxXqP
# 651  xFGyyf3tPhoUbHLXi-VkmK58gFA9qXsD
# 652  xQNVzxr2wYX-lCydlBtEMRWjFPKiDg79
# 5       123977           885
# 6        86833           756
# 7       126216          2175
# 8       146674          2006
# 9         8642            87
# 10       40345           751
# 11       27207           306
# 12       49825           607
# 13      240587          1116
# 14       79146          2230
# 15      125269           972
# 16       92431          1065
# 17      166927          3200
# 18      125519          1317
# 19       23869           339
# 20      177990          5172
# 21      125140          1554
# 22      225312          3060
# 23      371842          3317
# 24      380300          8617
# 25      310718          6681
# 26        2554            39
# 27      136060          1570
# 28       96166          2751
# 29       35311           388
# ..         ...           ...
# 644     140022          5322
# 645      25109          1488
# 646      39156          1063
# 647      19746           309
# 648       1801            26
# 649     121676          1644
# 650     284234          3858
# 651    1506363         22600
# 652      18303          1449
# 653      42970           766
# 654      34368          1070
# 655     228949          4909
# 656     163837          1756
# 657       4516            77
# 658      14336           485
# 659      32054           484
# 660     188412          6885
# 661     323865          4126
# 662      74875           706
# 663     330854          4545
# 664     172243         10145
# 665      50273          5112
# 666      91805          1827
# 667     248012          5595
# 668     102984           667
# 669     228997          6711
# 670     176527          3538
# 671     175975          2683
# 672     211291         18690
# 673     238650          4001
#
# [674 rows x 8 columns]

# %%
from keras.layers import Embedding, LSTM, Dense, Input
from keras.models import Sequential, Model
from keras import layers, preprocessing
import keras

# %% [markdown]
# ### Tokenize
#
# lets get the number of unique words and average caption length

# %%
texts = list([x.lower() for x in df['caption']])
texts[0][0:20]
# Out:
# 'the hell is this new'

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for text in texts:
    for i in range(0, len(text) - maxlen, step):
        sentences.append(text[i: i + maxlen])
        next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))
# Out:
# Number of sequences: 1240334

# %%
sentences[0]
# Out:
# 'the hell is this new music? give me the old music, bleach me'

# %%
next_chars[0]
# Out:
# ' '

# %%
texts[0][:61]
# Out:
# 'the hell is this new music? give me the old music, bleach me '

# %%
# List of unique characters in the corpus
chars = sorted(list(set(''.join(texts))))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)
# Out:
# Unique characters: 316

# %%
# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %% [markdown]
# ### Model
#
# Now make a model

# %%
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ### Training
#
# Now we need to train the model, after each epoch we will sample from the model to see how it is doing

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

def trainAndSample(numEpochs):
    for epoch in range(1, numEpochs):
        print('epoch', epoch)
        # Fit the model for 1 epoch on the available training data
        model.fit(x, y,
                  batch_size=128,
                  epochs=1)

        # Select a text seed at random
        text = random.choice(texts)
        start_index = random.randint(0, len(text) - maxlen - 1)
        generated_text = text[start_index: start_index + maxlen]
        print('--- Generating with seed: "' + generated_text + '"')

        for temperature in [0.2, 0.5, 1.0, 1.2]:
            print('------ temperature:', temperature)
            sys.stdout.write(generated_text)

            # We generate 400 characters
            for i in range(400):
                sampled = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(generated_text):
                    sampled[0, t, char_indices[char]] = 1.

                preds = model.predict(sampled, verbose=0)[0]
                next_index = sample(preds, temperature)
                next_char = chars[next_index]

                generated_text += next_char
                generated_text = generated_text[1:]

                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()

# %%
trainAndSample(5)
# Out:
# epoch 1
# Epoch 1/1
# 1240334/1240334 [==============================] - 1597s 1ms/step - loss: 1.7290
# --- Generating with seed: "'ve also "simplified" the fighting system. there's no specia"
